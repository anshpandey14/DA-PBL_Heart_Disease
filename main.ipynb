# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
# read csv file
df = pd.read_csv("Heart_new2.csv")
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
# 2            30          No    Male        65-69  White      Yes
# 3             0          No  Female        75-79  White       No
# 4             0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# ...

# %%
# checking shape
df.shape
# Out:
# (4725, 18)

# %%
# checking data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4725 entries, 0 to 4724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HeartDisease      4493 non-null   object
#  1   BMI               4725 non-null   float64
#  2   Smoking           4725 non-null   object
#  3   AlcoholDrinking   4725 non-null   object
#  4   Stroke            4725 non-null   object
#  5   PhysicalHealth    4725 non-null   int64
#  6   MentalHealth      4725 non-null   int64
#  7   DiffWalking       4725 non-null   object
#  8   Sex               4725 non-null   object
#  9   AgeCategory       4725 non-null   object
#  10  Race              4725 non-null   object
#  11  Diabetic          4725 non-null   object
#  12  PhysicalActivity  4725 non-null   object
#  13  GenHealth         4725 non-null   object
#  14  SleepTime         4725 non-null   int64
#  15  Asthma            4725 non-null   object
# ...

# %%
# checking duplicated values
df.duplicated().sum()
# Out:
# np.int64(231)

# %%
# removing duplicates
df1 = df[df.duplicated()]
df1
# Out:
#      HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 2182           No  19.85      No              No     No               0
# 3182           No  28.19      No              No     No               0
# 3397           No  26.54      No              No     No               0
# 3650           No  32.89     Yes              No     No               2
# 4061           No  25.84      No              No     No               0
# ...           ...    ...     ...             ...    ...             ...
# 4720           No  27.60     Yes             Yes     No               0
# 4721           No  42.07      No              No     No               2
# 4722          Yes  40.35      No              No     No              20
# 4723          NaN  28.59      No              No     No               0
# 4724          NaN  27.46     Yes              No     No               0
#
#       MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# ...

# %%
# removing duplicates
df.drop_duplicates(inplace=True)

# %%
# checking shape
df.shape
# Out:
# (4494, 18)

# %%
# checking null values
df.isnull().sum()
# Out:
# HeartDisease        225
# BMI                   0
# Smoking               0
# AlcoholDrinking       0
# Stroke                0
# PhysicalHealth        0
# MentalHealth          0
# DiffWalking           0
# Sex                   0
# AgeCategory           0
# Race                  0
# Diabetic              0
# PhysicalActivity      0
# GenHealth             0
# SleepTime             0
# Asthma                0
# KidneyDisease         0
# SkinCancer            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %%
# calculating mode
a = df['HeartDisease'].mode()[0]
a
# Out:
# 'No'

# %%
# filling null values
df['HeartDisease'] = df['HeartDisease'].fillna(a)

# %%
# again rechecking for null values
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
# visualization part
sns.countplot(x="HeartDisease", data=df)
plt.title("Heart Disease Distribution")
plt.show()

# %%
# for numerical columns
df.hist(figsize=(12,8))
plt.show()

# %%
# imp features
sns.countplot(x="Smoking", hue="HeartDisease", data=df)
plt.show()

# %%
sns.countplot(x="Diabetic", hue="HeartDisease", data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x="Sex", hue="HeartDisease", data=df)
plt.show()

# %%
sns.countplot(x="AgeCategory", hue="HeartDisease", data=df)
plt.xticks(rotation=45)
plt.show()

# %%
# outliers detection and removal
sns.boxplot(x="HeartDisease", y="BMI", data=df)
plt.show()

# %%
q1 = np.percentile(df['BMI'],25)
q1
# Out:
# np.float64(24.69)

# %%
q2 = np.percentile(df['BMI'],50)
q2
# Out:
# np.float64(28.25)

# %%
q3 = np.percentile(df['BMI'],75)
q3
# Out:
# np.float64(33.0)

# %%
IQR = q3-q1
IQR
# Out:
# np.float64(8.309999999999999)

# %%
LBR = q1 - 1.5 * IQR
LBR
# Out:
# np.float64(12.225000000000003)

# %%
UBR = q3 + 1.5 * IQR
UBR
# Out:
# np.float64(45.464999999999996)

# %%
print(df['BMI'].max())
print(df['BMI'].min())
# Out:
# 75.82
# 12.48

# %%
# Extreme Bmi cases are identified with as high as 75 and as low as 12 ,but not impossible one.
df1 = df[(df["BMI"] <= LBR) | (df["BMI"] >= UBR)]
df1
# Out:
#      HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 57             No  46.52     Yes              No     No              30
# 105            No  58.54      No              No     No              30
# 176            No  46.87     Yes             Yes     No               0
# 229            No  49.26      No              No     No              20
# 254            No  53.09      No              No     No              30
# ...           ...    ...     ...             ...    ...             ...
# 4340           No  48.04      No              No     No               8
# 4370          Yes  63.62      No             Yes     No               0
# 4383           No  45.73      No              No     No               0
# 4393           No  56.49     Yes              No     No              30
# 4481           No  54.75      No              No     No              30
#
#       MentalHealth DiffWalking     Sex AgeCategory   Race  \
# ...

# %%
sns.boxplot(x="HeartDisease", y="SleepTime", data=df)
plt.show()

# %%
q1 = np.percentile(df['SleepTime'],25)
q1
# Out:
# np.float64(6.0)

# %%
q2 = np.percentile(df['SleepTime'],50)
q2
# Out:
# np.float64(7.0)

# %%
q3 = np.percentile(df['SleepTime'],75)
q3
# Out:
# np.float64(8.0)

# %%
IQR = q3-q1
IQR
# Out:
# np.float64(2.0)

# %%
LBR = q1 - 1.5 * IQR
LBR
# Out:
# np.float64(3.0)

# %%
UBR = q3 + 1.5 * IQR
UBR
# Out:
# np.float64(11.0)

# %%
print(df['SleepTime'].max())
print(df['SleepTime'].min())
# Out:
# 20
# 1

# %%
# Extreme sleepTime cases are identified with as high as 20 and as low as 1, but not impossible one.
df2 = df[(df["SleepTime"] <= LBR) | (df["SleepTime"] >= UBR)]
df2
# Out:
#      HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 5             Yes  28.87     Yes              No     No               6
# 10            Yes  34.30     Yes              No     No              30
# 50             No  26.61      No              No     No               0
# 103            No  27.98      No              No     No               0
# 105            No  58.54      No              No     No              30
# ...           ...    ...     ...             ...    ...             ...
# 4339           No  22.50     Yes              No     No               0
# 4351           No  22.46     Yes             Yes     No               0
# 4383           No  45.73      No              No     No               0
# 4458           No  33.00      No              No     No               0
# 4490           No  43.85      No             Yes     No               7
#
#       MentalHealth DiffWalking     Sex  AgeCategory      Race  \
# ...

# %%
# out of 30 days,no of bad mental health days --> so no such outliers
print(df['MentalHealth'].max())
print(df['MentalHealth'].min())
# Out:
# 30
# 0

# %%
# out of 30 days no of bad physical health days --> so no such outliers
print(df['PhysicalHealth'].max())
print(df['PhysicalHealth'].min())
# Out:
# 30
# 0

# %%
# All four numerical values are checked for outliers.

# %%
# no such relation between numerical features
sns.pairplot(df[["BMI", "SleepTime", "PhysicalHealth", "MentalHealth"]])
plt.show()

# %%
# correlation data
c = df.select_dtypes(include='number').corr()
c
# Out:
#                      BMI  PhysicalHealth  MentalHealth  SleepTime
# BMI             1.000000        0.088563      0.067849  -0.056794
# PhysicalHealth  0.088563        1.000000      0.282274  -0.061779
# MentalHealth    0.067849        0.282274      1.000000  -0.148697
# SleepTime      -0.056794       -0.061779     -0.148697   1.000000

# %%
h= sns.heatmap(c,annot=True,fmt='.2f',cmap='coolwarm')
h.figure.set_size_inches(18,10)
plt.title('Correlation Matrix of Heart Disease Data')
plt.show()

# %%
# model building

# %%
#  converting categorical data into numerical one
df_new = pd.get_dummies(df, drop_first=True)
df_new.head()
# Out:
#      BMI  PhysicalHealth  MentalHealth  SleepTime  HeartDisease_Yes  \
# 0  16.60               3            30          5             False
# 1  20.34               0             0          7             False
# 2  26.58              20            30          8             False
# 3  24.21               0             0          6             False
# 4  23.71              28             0          8             False
#
#    Smoking_Yes  AlcoholDrinking_Yes  Stroke_Yes  DiffWalking_Yes  Sex_Male  \
# 0         True                False       False            False     False
# 1        False                False        True            False     False
# 2         True                False       False            False      True
# 3        False                False       False            False     False
# 4        False                False       False             True     False
#
#    ...  Diabetic_Yes  Diabetic_Yes (during pregnancy)  PhysicalActivity_Yes  \
# ...

# %%
# new columns
df_new.columns
# Out:
# Index(['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime',
#        'HeartDisease_Yes', 'Smoking_Yes', 'AlcoholDrinking_Yes', 'Stroke_Yes',
#        'DiffWalking_Yes', 'Sex_Male', 'AgeCategory_25-29', 'AgeCategory_30-34',
#        'AgeCategory_35-39', 'AgeCategory_40-44', 'AgeCategory_45-49',
#        'AgeCategory_50-54', 'AgeCategory_55-59', 'AgeCategory_60-64',
#        'AgeCategory_65-69', 'AgeCategory_70-74', 'AgeCategory_75-79',
#        'AgeCategory_80 or older', 'Race_Asian', 'Race_Black', 'Race_Hispanic',
#        'Race_Other', 'Race_White', 'Diabetic_No, borderline diabetes',
#        'Diabetic_Yes', 'Diabetic_Yes (during pregnancy)',
#        'PhysicalActivity_Yes', 'GenHealth_Fair', 'GenHealth_Good',
#        'GenHealth_Poor', 'GenHealth_Very good', 'Asthma_Yes',
#        'KidneyDisease_Yes', 'SkinCancer_Yes'],
#       dtype='object')

# %%
# separating independent and dependent variables
x = df_new.drop("HeartDisease_Yes", axis=1)
y = df_new["HeartDisease_Yes"]

# %%
print(x.shape)
print(y.shape)
# Out:
# (4494, 37)
# (4494,)

# %%
# import 
from sklearn.model_selection import train_test_split

# %%
#  splitting train-test data
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (3595, 37) (899, 37)
# (3595,) (899,)

# %%
# import - Logistic regression
from sklearn.linear_model import LogisticRegression

# %%
#  model training
model = LogisticRegression(max_iter=1000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# prediction
y_predict = model.predict(x_test)

# %%
#  import
from sklearn.metrics import accuracy_score

# %%
# Accuracy
accuracy = accuracy_score(y_test, y_predict)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9210233592880979

# %%
# import
from sklearn.metrics import confusion_matrix

# %%
# confusion matrix
cm = confusion_matrix(y_test, y_predict)
sns.heatmap(cm, annot=True, fmt='.2f')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
# import
from sklearn.metrics import classification_report

# %%
# classification report
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.98      0.96       826
#         True       0.54      0.21      0.30        73
#
#     accuracy                           0.92       899
#    macro avg       0.73      0.59      0.63       899
# weighted avg       0.90      0.92      0.90       899
